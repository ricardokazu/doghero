# %% [markdown]
# ### Discussion
# First we use the scraping process with scrapy, then some data manipulation.
#
# In a first look in the site, we come to realize that there are ... sale items in total, distributed between ... cities and ... types of sale:
#
# - Compra:
# - Aluguel:
#
# And then, there are ... types of products, each type of product has its own subtypes distributed like:
# - Apartamentos:
# - Casas:
#
#
# For this scraping, we will focus on categories that will help find answers for the questions:
#
# - What is the mean price for each city?
# - What is the city with most offers?
# - List the 5 cheapest and the most expensive.
#
# The categories used are:
#
# -
# -
#
# #### Scraping
#
# In this first step, it was imported the libraries needed for this notebook.

# %%
from scrapy.crawler import CrawlerProcess
from scrapy.utils.project import get_project_settings
from DogHero.spiders import imovelweb

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# In this next cell, the crawl is executed.

# %%
# %%time
process = CrawlerProcess(get_project_settings())
process.crawl('ImovelWebCrawl_final')

process.start() # the script will block here until the crawling is finished
# Out:
# 2018-10-30 00:38:22 [scrapy.utils.log] INFO: Scrapy 1.5.1 started (bot: DogHero)
# 2018-10-30 00:38:22 [scrapy.utils.log] INFO: Versions: lxml 4.2.1.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.0, w3lib 1.19.0, Twisted 18.9.0, Python 3.6.5 |Anaconda, Inc.| (default, Mar 29 2018, 13:32:41) [MSC v.1900 64 bit (AMD64)], pyOpenSSL 18.0.0 (OpenSSL 1.0.2o  27 Mar 2018), cryptography 2.2.2, Platform Windows-10-10.0.17134-SP0
# 2018-10-30 00:38:22 [scrapy.crawler] INFO: Overridden settings: {'BOT_NAME': 'DogHero', 'FEED_FORMAT': 'csv', 'FEED_URI': 'imovelwebcrawl.csv', 'NEWSPIDER_MODULE': 'DogHero.spiders', 'ROBOTSTXT_OBEY': True, 'SPIDER_MODULES': ['DogHero.spiders']}
# 2018-10-30 00:38:22 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2018-10-30 00:38:22 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2018-10-30 00:38:22 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2018-10-30 00:38:22 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2018-10-30 00:38:22 [scrapy.core.engine] INFO: Spider opened
# 2018-10-30 00:38:22 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-10-30 00:38:22 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2018-10-30 00:38:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/robots.txt> (referer: None)
# 2018-10-30 00:38:24 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_1.html>
# 2018-10-30 00:38:25 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_5.html>
# 2018-10-30 00:38:25 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_3.html>
# 2018-10-30 00:38:25 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_8.html>
# 2018-10-30 00:38:25 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_7.html>
# 2018-10-30 00:38:25 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_4.html>
# 2018-10-30 00:38:25 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_2.html>
# 2018-10-30 00:38:25 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_9.html>
# 2018-10-30 00:38:25 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_6.html>
# 2018-10-30 00:38:26 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_10.html>
# 2018-10-30 00:38:26 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_12.html>
# 2018-10-30 00:38:26 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_14.html>
# 2018-10-30 00:38:26 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_13.html>
# 2018-10-30 00:38:26 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_16.html>
# 2018-10-30 00:38:26 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_11.html>
# 2018-10-30 00:38:26 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_15.html>
# 2018-10-30 00:38:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:38:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:38:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:38:30 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET https://www.imovelweb.com.br/propriedades/casa-residencial-a-venda-icarai-niteroi.-2940047421.html> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2018-10-30 00:38:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:38:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:38:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:38:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:38:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:38:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:38:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:38:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:38:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:38:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:38:34 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_17.html>
# 2018-10-30 00:38:34 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_18.html>
# 2018-10-30 00:38:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:38:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:38:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:38:36 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/propriedades/teste-antes:-fusion-e-vision-100-mobiliados!-2937260242.html> from <GET https://www.imovelweb.com.br/propriedades/teste-antes-:-fusion-e-vision-100-mobiliados-!!-2937260242.html#map>
# 2018-10-30 00:38:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/retrato-paulista-2921325194.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/retrato-paulista-2921325194.html>
# {'commonareas': 'Fitness/Sala de Ginástica',
#  'privateareas': 'Escritório',
#  'title': 'Retrato Paulista'}
# 2018-10-30 00:38:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/casa-residencial-a-venda-icarai-niteroi.-2940047421.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/casa-residencial-a-venda-icarai-niteroi.-2940047421.html>
# {'IPTU': '100',
#  'Venda': '580000',
#  'area_total': '85',
#  'area_util': '85',
#  'banheiro': '2',
#  'city': 'Niterói',
#  'neigghborhood': 'Icaraí',
#  'privateareas': 'Esgoto',
#  'quarto': '2',
#  'saletype': 'Casa',
#  'street': 'Rua Presidente Backer 184',
#  'title': 'Casa Residencial à Venda, Icaraí, Niterói.'}
# 2018-10-30 00:38:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/comercial-a-venda-na-vila-ferrari-ii-2927979836.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/comercial-a-venda-na-vila-ferrari-ii-2927979836.html>
# {'Venda': '796000',
#  'age_imovel': 'Breve lançamento',
#  'area_total': '2041',
#  'area_util': '2041',
#  'city': 'Campo Largo',
#  'neigghborhood': 'Vila Ferrari II',
#  'quarto': '0',
#  'saletype': 'Comercial',
#  'street': 'AGOSTINHO MOCELIN 700',
#  'title': 'Comercial à Venda - na Vila Ferrari II'}
# 2018-10-30 00:38:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/casa-a-venda-em-condominio-estancia-marambaia-2937728169.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/chacara-residencial-a-venda-campininha-quatro-2939127047.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/casa-a-venda-em-condominio-estancia-marambaia-2937728169.html>
# {'Condominio': '668',
#  'IPTU': '650',
#  'Venda': '5800000',
#  'age_imovel': '2',
#  'area_total': '1200',
#  'area_util': '700',
#  'banheiro': '8',
#  'city': 'Vinhedo',
#  'commonareas': 'Pista de cooper',
#  'neigghborhood': 'Condomínio Estância Marambaia',
#  'privateareas': 'Playground',
#  'quarto': '5',
#  'saletype': 'Casa',
#  'street': 'Sob Consulta 0',
#  'suite': '5',
#  'title': 'Casa à Venda em Condomínio Estância Marambaia',
#  'vaga': '4'}
# 2018-10-30 00:38:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/chacara-residencial-a-venda-campininha-quatro-2939127047.html>
# {'Venda': '500000',
#  'area_total': '31000',
#  'area_util': '31000',
#  'banheiro': '4',
#  'city': 'Quatro Barras',
#  'neigghborhood': 'Palmitalzinho',
#  'privateareas': 'Churrasqueira',
#  'quarto': '2',
#  'saletype': 'Rural',
#  'street': 'Estrada Velha Graciosa 0',
#  'title': 'Chácara Residencial à Venda, Campininha, Quatro Barras.',
#  'vaga': '7'}
# 2018-10-30 00:38:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/promocao-a-vista!-apartamento-3-quartos-ao-lado-do-2939669830.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/casa-a-venda-e-para-aluguel-em-condominio-morada-do-2932880818.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/promocao-a-vista!-apartamento-3-quartos-ao-lado-do-2939669830.html>
# {'Venda': '426900',
#  'age_imovel': '1',
#  'area_util': '71',
#  'banheiro': '2',
#  'city': 'Curitiba',
#  'commonareas': 'Espaço Gourmet',
#  'diverseareas': 'Andares',
#  'neigghborhood': 'Santa Felicidade',
#  'privateareas': 'Suítes',
#  'quarto': '3',
#  'saletype': 'Apartamento',
#  'street': 'Rua Tobias de Macedo Júnior, 1138',
#  'suite': '1',
#  'title': 'Promoção à Vista! Apartamento 3 Quartos Ao Lado Do Parque Barigui',
#  'vaga': '2'}
# 2018-10-30 00:38:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/casa-a-venda-e-para-aluguel-em-condominio-morada-do-2932880818.html>
# {'Aluguel': '6500',
#  'Condominio': '2500',
#  'IPTU': '5000',
#  'Venda': '2790000',
#  'age_imovel': '18',
#  'area_total': '2000',
#  'area_util': '370',
#  'banheiro': '8',
#  'city': 'Vinhedo',
#  'commonareas': 'Campo de futebol',
#  'neigghborhood': 'Centro',
#  'privateareas': 'Mobiliado',
#  'quarto': '4',
#  'saletype': 'Casa',
#  'street': 'Sob Consulta 25',
#  'suite': '4',
#  'title': 'Casa Á Venda E para Aluguel em Condomínio Morada Do Sol',
#  'vaga': '6'}
# 2018-10-30 00:38:38 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/propriedades/apto.-2-dor.-c-suite-tupi-vista-2938996622.html> from <GET https://www.imovelweb.com.br/propriedades/apto.-2-dor.c-suite-tupi-vista-2938996622.html#map>
# 2018-10-30 00:38:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/ed.-weekend-studio-com-vaga-ao-lado-do-museo-do-olho-2938734153.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/ed.-weekend-studio-com-vaga-ao-lado-do-museo-do-olho-2938734153.html>
# {'Venda': '200000',
#  'age_imovel': '1',
#  'area_total': '50',
#  'area_util': '27',
#  'banheiro': '1',
#  'city': 'Curitiba',
#  'commonareas': 'Espaço Gourmet',
#  'neigghborhood': 'Cristo Rei',
#  'privateareas': 'Piso frio',
#  'quarto': '1',
#  'saletype': 'Apartamento',
#  'street': 'R. Manoel Eufrásio',
#  'suite': '0',
#  'title': 'Ed. Weekend - Studio Com Vaga Ao Lado Do Museo Do Olho',
#  'vaga': '1'}
# 2018-10-30 00:38:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/apartamento-para-aluguel-em-lourdes-2940001445.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/apartamento-fazenda-gleba-palhano-2939346109.html> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/apartamento-para-aluguel-em-lourdes-2940001445.html>
# {'Aluguel': '1300',
#  'Condominio': '286',
#  'IPTU': '48',
#  'area_util': '56',
#  'banheiro': '1',
#  'city': 'Belo Horizonte',
#  'commonareas': 'Salão de festas',
#  'neigghborhood': 'Lourdes',
#  'privateareas': 'Armário embutido',
#  'quarto': '1',
#  'saletype': 'Apartamento',
#  'street': 'Rua Guajararas 1172',
#  'suite': '0',
#  'title': 'Apartamento para Aluguel - em Lourdes',
#  'vaga': '0'}
# 2018-10-30 00:38:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/apartamento-fazenda-gleba-palhano-2939346109.html>
# {'Condominio': '700',
#  'Venda': '1040000',
#  'area_total': '299',
#  'area_util': '183',
#  'banheiro': '0',
#  'privateareas': 'Playground',
#  'quarto': '3',
#  'saletype': 'Apartamento',
#  'suite': '1',
#  'title': 'Apartamento - Fazenda Gleba Palhano',
#  'vaga': '0'}
# 2018-10-30 00:38:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:38:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:38:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/-apartamento-a-venda-com-vista-arborizada-c-2-dorms-2938555195.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/apartamento-a-venda-na-barra-da-tijuca-2936146610.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/teste-antes:-fusion-e-vision-100-mobiliados!-2937260242.html> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/-apartamento-a-venda-com-vista-arborizada-c-2-dorms-2938555195.html>
# {'Condominio': '590',
#  'IPTU': '18',
#  'Venda': '360000',
#  'age_imovel': '15',
#  'area_total': '155',
#  'area_util': '62',
#  'banheiro': '1',
#  'city': 'São Paulo',
#  'commonareas': 'Fitness/Sala de Ginástica',
#  'diverseareas': 'Aceita FGTS',
#  'neigghborhood': 'Jardim Marajoara',
#  'privateareas': 'Carpete de madeira',
#  'quarto': '2',
#  'saletype': 'Apartamento',
#  'street': 'Rua Dr. Silva Melo, 132',
#  'suite': '0',
#  'title': '*apartamento à Venda*com Vista Arborizada, C/2 Dorms, Clube, no '
#           'Jardim Marajoara',
#  'vaga': '1'}
# 2018-10-30 00:38:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/apartamento-a-venda-na-barra-da-tijuca-2936146610.html>
# {'Condominio': '1900',
#  'Venda': '1600000',
#  'area_util': '126',
#  'city': 'Rio de Janeiro',
#  'neigghborhood': 'Barra da Tijuca',
#  'quarto': '3',
#  'saletype': 'Apartamento',
#  'street': 'Endereço não informado',
#  'suite': '1',
#  'title': 'Apartamento à Venda - na Barra Da Tijuca',
#  'vaga': '2'}
# 2018-10-30 00:38:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/teste-antes:-fusion-e-vision-100-mobiliados!-2937260242.html>
# {'Aluguel': '2500',
#  'Condominio': '600',
#  'IPTU': '900',
#  'Venda': '265000',
#  'age_imovel': '3',
#  'area_total': '27',
#  'area_util': '27',
#  'banheiro': '1',
#  'city': 'Brasília',
#  'commonareas': 'Fitness/Sala de Ginástica',
#  'diverseareas': 'Andares',
#  'neigghborhood': 'Asa Norte',
#  'privateareas': 'Suítes',
#  'quarto': '1',
#  'saletype': 'Apartamento',
#  'street': 'SHN QUADRA 1',
#  'suite': '1',
#  'title': 'Teste Antes: Fusion E Vision 100% Mobiliados!',
#  'vaga': '1'}
# 2018-10-30 00:38:42 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/propriedades/more-a-50-m-do-jardim-botanico.-apartamento-de-3-2937329546.html> from <GET https://www.imovelweb.com.br/propriedades/more-a-50-metros-do-jardim-botanico...apartamento-de-3-2937329546.html#map>
# 2018-10-30 00:38:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/maravilhoso-garden-o-privilegio-de-ter-o-parque-2938938656.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/maravilhoso-garden-o-privilegio-de-ter-o-parque-2938938656.html>
# {'Condominio': '2800',
#  'IPTU': '1800',
#  'Venda': '5424000',
#  'age_imovel': 'Breve lançamento',
#  'area_total': '363',
#  'area_util': '363',
#  'banheiro': '6',
#  'city': 'São Paulo',
#  'commonareas': 'Fitness/Sala de Ginástica',
#  'neigghborhood': 'Jardim Paulista',
#  'privateareas': 'Guarita',
#  'quarto': '3',
#  'saletype': 'Apartamento',
#  'street': 'R Guarará',
#  'suite': '1',
#  'title': 'Maravilhoso Garden - O Privilégio De Ter O Parque Ibirapuera Como '
#           'Vizinho',
#  'vaga': '4'}
# 2018-10-30 00:38:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/apartamento-a-venda-no-centro-2930303475.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/apartamento-a-venda-no-centro-2930303475.html>
# {'Venda': '235000',
#  'area_total': '93',
#  'area_util': '60',
#  'banheiro': '2',
#  'city': 'São José dos Pinhais',
#  'commonareas': 'Espaço Gourmet',
#  'neigghborhood': 'Centro',
#  'privateareas': 'Churrasqueira',
#  'quarto': '3',
#  'saletype': 'Apartamento',
#  'street': 'Rua Doutor Motta Junior 1400',
#  'suite': '1',
#  'title': 'Apartamento à Venda - no Centro',
#  'vaga': '2'}
# 2018-10-30 00:38:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/oportunidade-na-planta-em-meia-praia-com-grande-2938474572.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/oportunidade-na-planta-em-meia-praia-com-grande-2938474572.html>
# {'Condominio': '410',
#  'IPTU': '870',
#  'Venda': '580000',
#  'age_imovel': 'Em construção',
#  'area_util': '138',
#  'banheiro': '4',
#  'city': 'Itapema',
#  'commonareas': 'Espaço Gourmet',
#  'neigghborhood': 'Meia Praia',
#  'privateareas': 'Suítes',
#  'quarto': '3',
#  'saletype': 'Apartamento',
#  'street': 'Rua 284',
#  'suite': '3',
#  'title': 'Oportunidade na Planta em Meia Praia Com Grande Valorização (Laz - '
#           '664).',
#  'vaga': '3'}
# 2018-10-30 00:38:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/apartamento-a-venda-no-tatuape-2940116299.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/casa-condominio-fechado-viver-sumare-lazer-completo-2936268460.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/oportunidade-imperdivel-para-adquirir-seu-imovel-no-2939326083.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/apartamento-a-venda-no-tatuape-2940116299.html>
# {'Condominio': '750',
#  'IPTU': '80',
#  'Venda': '650000',
#  'age_imovel': '18',
#  'area_util': '106',
#  'banheiro': '2',
#  'city': 'São Paulo',
#  'commonareas': 'Forno de pizza',
#  'neigghborhood': 'Chácara Califórnia',
#  'privateareas': 'Piso frio',
#  'quarto': '3',
#  'saletype': 'Apartamento',
#  'street': 'Sete de Outubro',
#  'suite': '1',
#  'title': 'Apartamento à Venda no Tatuapé',
#  'vaga': '2'}
# 2018-10-30 00:38:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/casa-condominio-fechado-viver-sumare-lazer-completo-2936268460.html>
# {'Condominio': '250',
#  'IPTU': '300',
#  'Venda': '228000',
#  'age_imovel': '1',
#  'area_total': '140',
#  'area_util': '47',
#  'banheiro': '1',
#  'city': 'Sumaré',
#  'commonareas': 'Espaço Gourmet',
#  'diverseareas': 'Aceita FGTS',
#  'neigghborhood': 'Real Park',
#  'privateareas': 'Permite animais',
#  'quarto': '2',
#  'saletype': 'Casa',
#  'street': 'Avenida Cabo Pedro Hoffman',
#  'suite': '0',
#  'title': 'Casa Condomínio Fechado Viver Sumaré, Lazer Completo, 2 '
#           'Dormitórios, 2 Vagas',
#  'vaga': '2'}
# 2018-10-30 00:38:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/oportunidade-imperdivel-para-adquirir-seu-imovel-no-2939326083.html>
# {'Condominio': '200',
#  'Venda': '90000',
#  'age_imovel': '30',
#  'area_total': '40',
#  'area_util': '40',
#  'banheiro': '1',
#  'city': 'Salvador',
#  'commonareas': 'Interfone',
#  'diverseareas': 'Aceita FGTS',
#  'neigghborhood': 'Centro',
#  'privateareas': 'Armário de cozinha',
#  'quarto': '1',
#  'saletype': 'Apartamento',
#  'street': 'RUA RUY BARBOSA',
#  'suite': '0',
#  'title': 'Oportunidade Imperdível para Adquirir Seu Imóvel no Centro!',
#  'vaga': '0'}
# 2018-10-30 00:38:45 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/propriedades/belissima-chacara-em-socorro-925-m-sup2-2933497252.html> from <GET https://www.imovelweb.com.br/propriedades/belissima-chacara-em-socorro-925m-2933497252.html#map>
# 2018-10-30 00:38:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/apartamento-a-venda-ed.-farol-ilha-da-paz-centro-2938392476.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/sobrado-a-venda-com-3-dormitorios-na-vila-prudente-2940047475.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/apartamento-a-venda-ed.-farol-ilha-da-paz-centro-2938392476.html>
# {'Condominio': '400',
#  'Venda': '1240000',
#  'age_imovel': '1',
#  'area_total': '227',
#  'area_util': '121',
#  'banheiro': '2',
#  'city': 'Balneário Camboriú',
#  'neigghborhood': 'Centro',
#  'privateareas': 'Suítes',
#  'quarto': '3',
#  'saletype': 'Apartamento',
#  'street': 'Rua 1101 324',
#  'suite': '3',
#  'title': 'Apartamento à Venda, Ed. Farol Ilha Da Paz, Centro, Balneário '
#           'Camboriú.',
#  'vaga': '2'}
# 2018-10-30 00:38:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/sobrado-a-venda-com-3-dormitorios-na-vila-prudente-2940047475.html>
# {'Venda': '480000',
#  'area_total': '110',
#  'area_util': '110',
#  'banheiro': '3',
#  'city': 'São Paulo',
#  'commonareas': 'Acesso asfaltado',
#  'neigghborhood': 'Vila Alpina',
#  'privateareas': 'Suítes',
#  'quarto': '3',
#  'saletype': 'Casa',
#  'street': 'Rua Catuaba 476',
#  'suite': '1',
#  'title': 'Sobrado à Venda, Com 3 Dormitórios, na Vila Prudente',
#  'vaga': '2'}
# 2018-10-30 00:38:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/apto.-2-dor.-c-suite-tupi-vista-2938996622.html> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/apto.-2-dor.-c-suite-tupi-vista-2938996622.html>
# {'Condominio': '418',
#  'IPTU': '280',
#  'Venda': '320000',
#  'age_imovel': '10',
#  'area_util': '88',
#  'banheiro': '2',
#  'city': 'Praia Grande',
#  'commonareas': 'Salão de festas',
#  'diverseareas': 'Andares',
#  'neigghborhood': 'Vila Tupi',
#  'privateareas': 'Piso frio',
#  'quarto': '2',
#  'saletype': 'Apartamento',
#  'street': 'Rua Guaicurus',
#  'suite': '1',
#  'title': 'Apto. 2 Dor. C/suite Tupi Vista',
#  'vaga': '1'}
# 2018-10-30 00:38:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/ca-05-ed.-san-raphael!-de-canto-reformado!-2939547773.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/ca-05-ed.-san-raphael!-de-canto-reformado!-2939547773.html>
# {'Condominio': '710',
#  'Venda': '550000',
#  'age_imovel': '8',
#  'area_util': '60',
#  'banheiro': '2',
#  'city': 'Brasília',
#  'commonareas': 'Fitness/Sala de Ginástica',
#  'diverseareas': 'Aceita FGTS',
#  'neigghborhood': 'Centro de Atividades',
#  'privateareas': 'Suítes',
#  'quarto': '2',
#  'saletype': 'Apartamento',
#  'street': 'CA 5 (Centro de Atividades)',
#  'suite': '1',
#  'title': 'Ca 05 - Ed. San Raphael! De Canto, Reformado!',
#  'vaga': '1'}
# 2018-10-30 00:38:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/studio-no-agua-verde.-2938300101.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/apartamento-2-quartos-recreio-pontal-oceanico-maui-2938996600.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/studio-no-agua-verde.-2938300101.html>
# {'Venda': '300150',
#  'age_imovel': '4',
#  'area_total': '51',
#  'area_util': '34',
#  'banheiro': '1',
#  'city': 'Curitiba',
#  'commonareas': 'Fitness/Sala de Ginástica',
#  'neigghborhood': 'Vila Izabel',
#  'privateareas': 'Lavanderia',
#  'quarto': '1',
#  'saletype': 'Apartamento',
#  'street': 'Republica Argentina 1037',
#  'suite': '0',
#  'title': 'Studio no Água Verde.',
#  'vaga': '0'}
# 2018-10-30 00:38:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/casa-duplex-com-2-quartos-fanchen-queimados-rj-2939194394.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/apartamento-2-quartos-recreio-pontal-oceanico-maui-2938996600.html>
# {'Condominio': '750',
#  'Venda': '439000',
#  'age_imovel': '1',
#  'area_total': '70',
#  'area_util': '70',
#  'banheiro': '1',
#  'city': 'Rio de Janeiro',
#  'commonareas': 'Fitness/Sala de Ginástica',
#  'diverseareas': 'Aceita FGTS',
#  'neigghborhood': 'Recreio dos Bandeirantes',
#  'privateareas': 'Suítes',
#  'quarto': '2',
#  'saletype': 'Apartamento',
#  'street': 'Rua Nilton Santos 1.850',
#  'suite': '1',
#  'title': 'Apartamento 2 Quartos Recreio - Pontal Oceânico - Maui - Calçada',
#  'vaga': '1'}
# 2018-10-30 00:38:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/casa-duplex-com-2-quartos-fanchen-queimados-rj-2939194394.html>
# {'Venda': '140000',
#  'age_imovel': '1',
#  'area_total': '60',
#  'area_util': '60',
#  'banheiro': '2',
#  'city': 'Queimados',
#  'diverseareas': 'Aceita FGTS',
#  'neigghborhood': 'Vila do Tinguá',
#  'quarto': '2',
#  'saletype': 'Casa',
#  'street': 'rua divino alcides',
#  'suite': '0',
#  'title': 'Casa Duplex Com 2 Quartos Fanchen Queimados Rj',
#  'vaga': '1'}
# 2018-10-30 00:38:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/conjunto-comercial-para-locacao-batel-curitiba.-2937700151.html> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/conjunto-comercial-para-locacao-batel-curitiba.-2937700151.html>
# {'Aluguel': '1380',
#  'Condominio': '320',
#  'IPTU': '102',
#  'age_imovel': '15',
#  'area_total': '71',
#  'area_util': '50',
#  'banheiro': '1',
#  'city': 'Curitiba',
#  'commonareas': 'Acesso asfaltado',
#  'neigghborhood': 'Batel',
#  'privateareas': 'Esgoto',
#  'quarto': '0',
#  'saletype': 'Comercial',
#  'street': 'Avenida Sete de Setembro',
#  'title': 'Conjunto Comercial para Locação, Batel, Curitiba.'}
# 2018-10-30 00:38:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/terreno-plano-aldeia-da-serra-morada-das-estrelas-2934352216.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/terreno-plano-aldeia-da-serra-morada-das-estrelas-2934352216.html>
# {'Condominio': '600',
#  'IPTU': '250',
#  'Venda': '450000',
#  'area_total': '532',
#  'area_util': '532',
#  'banheiro': '0',
#  'city': 'Barueri',
#  'neigghborhood': 'Aldeia da Serra',
#  'saletype': 'Terreno',
#  'street': 'Procion',
#  'title': 'Terreno Plano Aldeia Da Serra Morada Das Estrelas',
#  'vaga': '0'}
# 2018-10-30 00:38:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/-collinas-parque-dos-principes!-oportunidade!-2938687867.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/-collinas-parque-dos-principes!-oportunidade!-2938687867.html>
# {'Condominio': '900',
#  'IPTU': '200',
#  'Venda': '689999',
#  'age_imovel': '6',
#  'area_total': '122',
#  'area_util': '122',
#  'banheiro': '3',
#  'city': 'São Paulo',
#  'commonareas': 'Fitness/Sala de Ginástica',
#  'diverseareas': 'Aceita FGTS',
#  'neigghborhood': 'Rio Pequeno',
#  'privateareas': 'Suítes',
#  'quarto': '3',
#  'saletype': 'Apartamento',
#  'street': 'Avenida Escola Politécnica',
#  'suite': '3',
#  'title': '- Collinas Parque Dos Príncipes! Oportunidade!',
#  'vaga': '2'}
# 2018-10-30 00:38:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/more-a-50-m-do-jardim-botanico.-apartamento-de-3-2937329546.html> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/more-a-50-m-do-jardim-botanico.-apartamento-de-3-2937329546.html>
# {'Condominio': '550',
#  'Venda': '399000',
#  'age_imovel': '1',
#  'area_total': '70',
#  'area_util': '70',
#  'banheiro': '2',
#  'city': 'São Paulo',
#  'commonareas': 'Espaço Gourmet',
#  'neigghborhood': 'Saúde',
#  'quarto': '3',
#  'saletype': 'Apartamento',
#  'street': 'Avenida Miguel Estefno',
#  'suite': '1',
#  'title': 'More A 50 m Do Jardim Botânico. Apartamento De 3 Dormitórios, 2 '
#           'Vagas',
#  'vaga': '2'}
# 2018-10-30 00:38:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/casa-em-sjpinhais-com-facil-acesso-para-ctba-2927670230.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/casa-em-sjpinhais-com-facil-acesso-para-ctba-2927670230.html>
# {'Venda': '290000',
#  'area_total': '200',
#  'area_util': '130',
#  'banheiro': '2',
#  'city': 'São José dos Pinhais',
#  'commonareas': 'Sistema de alarme',
#  'neigghborhood': 'Afonso Pena',
#  'privateareas': 'Copa',
#  'quarto': '3',
#  'saletype': 'Casa',
#  'street': 'Rua Olívio Setim 7',
#  'suite': '1',
#  'title': 'Casa em Sjpinhais Com Fácil Acesso para Ctba',
#  'vaga': '4'}
# 2018-10-30 00:38:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/verissimo-mooca-2934085960.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/verissimo-mooca-2934085960.html>
# {'title': 'Veríssimo Mooca'}
# 2018-10-30 00:38:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/apartamento-a-venda-em-curitiba.-2936753132.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/apartamento-a-venda-em-curitiba.-2936753132.html>
# {'Venda': '249724',
#  'area_total': '54',
#  'area_util': '41',
#  'banheiro': '1',
#  'city': 'Curitiba',
#  'commonareas': 'Salão de festas',
#  'neigghborhood': 'Alto da XV',
#  'privateareas': 'Churrasqueira',
#  'quarto': '2',
#  'saletype': 'Apartamento',
#  'street': 'Rua Schiller 352',
#  'title': 'Apartamento à Venda em Curitiba.'}
# 2018-10-30 00:38:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/belissima-chacara-em-socorro-925-m-sup2-2933497252.html> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/belissima-chacara-em-socorro-925-m-sup2-2933497252.html>
# {'Venda': '390000',
#  'area_total': '925',
#  'area_util': '200',
#  'banheiro': '3',
#  'commonareas': 'Poço artesiano',
#  'privateareas': 'Cerca',
#  'quarto': '2',
#  'saletype': 'Rural',
#  'suite': '1',
#  'title': 'Belissima Chacara em Socorro 925 m&sup2;',
#  'vaga': '5'}
# 2018-10-30 00:38:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/apartamento-a-venda-no-bom-jesus-2937256684.html> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/apartamento-a-venda-no-bom-jesus-2937256684.html>
# {'Condominio': '135',
#  'Venda': '180000',
#  'area_total': '85',
#  'area_util': '85',
#  'banheiro': '2',
#  'quarto': '2',
#  'saletype': 'Apartamento',
#  'suite': '1',
#  'title': 'Apartamento à Venda - no Bom Jesus',
#  'vaga': '1'}
# 2018-10-30 00:38:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/rural-a-venda-nas-chacaras-reunidas-igarapes-2939020271.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/rural-a-venda-nas-chacaras-reunidas-igarapes-2939020271.html>
# {'Venda': '100000',
#  'banheiro': '1',
#  'quarto': '2',
#  'saletype': 'Rural',
#  'title': 'Rural à Venda - nas Chácaras Reunidas Igarapés',
#  'vaga': '1'}
# 2018-10-30 00:38:52 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/propriedades/oportunidade-de-verdade!-apartamento-2-dormitorios-2938973994.html> from <GET https://www.imovelweb.com.br/propriedades/oportunidade-de-verdade!!-apartamento-2-dormitorios-2938973994.html#map>
# 2018-10-30 00:38:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/quartier-campo-belo-2923335007.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/quartier-campo-belo-2923335007.html>
# {'commonareas': 'Fitness/Sala de Ginástica', 'title': 'Quartier Campo Belo'}
# 2018-10-30 00:38:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/casa-a-venda-em-ceramica-2939932395.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/casa-a-venda-em-ceramica-2939932395.html>
# {'IPTU': '150',
#  'Venda': '630000',
#  'area_total': '144',
#  'area_util': '177',
#  'banheiro': '3',
#  'city': 'São Caetano do Sul',
#  'neigghborhood': 'Cerâmica',
#  'privateareas': 'Quintal',
#  'quarto': '3',
#  'saletype': 'Casa',
#  'street': 'Geovanina Borges Duarte',
#  'suite': '1',
#  'title': 'Casa à Venda - em Cerâmica',
#  'vaga': '2'}
# 2018-10-30 00:38:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/unique-alta-vista-2921328219.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/unique-alta-vista-2921328219.html>
# {'commonareas': 'Espaço Gourmet',
#  'privateareas': 'Deck',
#  'title': 'Unique Alta Vista'}
# 2018-10-30 00:38:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/sobrado-com-03-suites-em-porto-belo-2937779315.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/casa-para-aluguel-no-campo-belo-2939972743.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/sobrado-com-03-suites-em-porto-belo-2937779315.html>
# {'Venda': '340000',
#  'age_imovel': '2',
#  'area_total': '67',
#  'area_util': '67',
#  'banheiro': '1',
#  'city': 'Porto Belo',
#  'neigghborhood': 'Pereque',
#  'privateareas': 'Suítes',
#  'quarto': '3',
#  'saletype': 'Casa',
#  'street': 'RUA MARIO WALENDOWSKY',
#  'suite': '3',
#  'title': 'Sobrado Com 03 Suítes em Porto Belo',
#  'vaga': '4'}
# 2018-10-30 00:38:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/sobrado-lindo-de-frente-para-o-mar-2940094081.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/casa-para-aluguel-no-campo-belo-2939972743.html>
# {'Aluguel': '6000',
#  'IPTU': '786',
#  'area_util': '300',
#  'banheiro': '5',
#  'city': 'São Paulo',
#  'neigghborhood': 'Campo Belo',
#  'privateareas': 'Armário embutido',
#  'quarto': '4',
#  'saletype': 'Casa',
#  'street': 'Rua Bernardino de Campos 1148',
#  'suite': '2',
#  'title': 'Casa para Aluguel - no Campo Belo',
#  'vaga': '0'}
# 2018-10-30 00:38:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/sobrado-lindo-de-frente-para-o-mar-2940094081.html>
# {'IPTU': '1400',
#  'Venda': '650000',
#  'age_imovel': '5',
#  'area_total': '248',
#  'area_util': '251',
#  'banheiro': '2',
#  'city': 'Pontal do Paraná',
#  'diverseareas': 'Aceita FGTS',
#  'neigghborhood': 'Pontal do Sul',
#  'privateareas': 'Suítes',
#  'quarto': '3',
#  'saletype': 'Casa',
#  'street': 'Av. Dep. Aníbal Khury, 19809',
#  'suite': '2',
#  'title': 'Sobrado Lindo De Frente para O Mar',
#  'vaga': '2'}
# 2018-10-30 00:38:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/retrato-pinheiros-2930591119.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/retrato-pinheiros-2930591119.html>
# {'commonareas': 'Espaço Gourmet', 'title': 'Retrato Pinheiros'}
# 2018-10-30 00:38:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/apartamento-varzea-da-barra-funda-2939431009.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/apartamento-varzea-da-barra-funda-2939431009.html>
# {'Condominio': '450',
#  'IPTU': '100',
#  'Venda': '509500',
#  'age_imovel': 'Breve lançamento',
#  'area_total': '58',
#  'area_util': '58',
#  'banheiro': '2',
#  'city': 'São Paulo',
#  'commonareas': 'Espaço Gourmet',
#  'neigghborhood': 'Várzea da Barra Funda',
#  'privateareas': 'Aceita Financiamento',
#  'quarto': '2',
#  'saletype': 'Apartamento',
#  'street': 'AVENIDA MARQUÊS DE SÃO VICENTE 341',
#  'suite': '1',
#  'title': 'Apartamento - Várzea Da Barra Funda',
#  'vaga': '1'}
# 2018-10-30 00:38:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/chacara-sitio-com-2-piscinas-com-prainha-e-com-2-2936396785.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/chacara-sitio-com-2-piscinas-com-prainha-e-com-2-2936396785.html>
# {'IPTU': '1300',
#  'Venda': '689000000',
#  'age_imovel': '1',
#  'area_total': '3750',
#  'area_util': '3750',
#  'banheiro': '7',
#  'city': 'Santa Isabel',
#  'commonareas': 'Espaço Gourmet',
#  'neigghborhood': 'Centro',
#  'privateareas': 'Suítes',
#  'quarto': '14',
#  'saletype': 'Rural',
#  'street': 'Rua Suzano, 480',
#  'suite': '2',
#  'title': 'Chácara / Sitio Com 2 Piscinas Com Prainha E Com 2 Casas em Santa '
#           'Isabel - Sp',
#  'vaga': '12'}
# 2018-10-30 00:38:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/oportunidade-alto-padrao-2938519311.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/oportunidade-alto-padrao-2938519311.html>
# {'Venda': '1300000',
#  'age_imovel': 'Breve lançamento',
#  'area_total': '280',
#  'area_util': '144',
#  'banheiro': '5',
#  'city': 'Balneário Camboriú',
#  'commonareas': 'Espaço Gourmet',
#  'diverseareas': 'Andares',
#  'neigghborhood': 'Centro',
#  'privateareas': 'Suítes',
#  'quarto': '4',
#  'saletype': 'Apartamento',
#  'street': 'RUA 3700 415',
#  'suite': '4',
#  'title': 'Oportunidade Alto Padrão',
#  'vaga': '3'}
# 2018-10-30 00:38:55 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_19.html>
# 2018-10-30 00:38:56 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/propriedades/apartamento-a-venda-com-138-m-sup2--brooklin-sao-2939508198.html> from <GET https://www.imovelweb.com.br/propriedades/apartamento-a-venda-com-138-m-brooklin-sao-paulo.-2939508198.html#map>
# 2018-10-30 00:38:56 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_20.html>
# 2018-10-30 00:38:56 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_21.html>
# 2018-10-30 00:38:56 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_22.html>
# 2018-10-30 00:38:57 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_23.html>
# 2018-10-30 00:38:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/centro-de-pinhais:-suite-sacada-c-churrasqueira-e-2939266708.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:57 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_24.html>
# 2018-10-30 00:38:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/centro-de-pinhais:-suite-sacada-c-churrasqueira-e-2939266708.html>
# {'Condominio': '150',
#  'IPTU': '578',
#  'Venda': '289000',
#  'age_imovel': 'Breve lançamento',
#  'area_total': '107',
#  'area_util': '81',
#  'banheiro': '1',
#  'city': 'Pinhais',
#  'commonareas': 'Interfone',
#  'diverseareas': 'Aceita FGTS',
#  'neigghborhood': 'Centro',
#  'privateareas': 'Suítes',
#  'quarto': '3',
#  'saletype': 'Apartamento',
#  'street': 'Rua Vinte e Cinco de Agosto',
#  'suite': '1',
#  'title': 'Centro De Pinhais: Suíte, Sacada C/ Churrasqueira E Elevador',
#  'vaga': '1'}
# 2018-10-30 00:38:57 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.imovelweb.com.br/imoveis.html> from <GET https://www.imovelweb.com.br/imoveis-pagina-_25.html>
# 2018-10-30 00:38:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/quartier-brooklin-2937025954.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/quartier-brooklin-2937025954.html>
# {'commonareas': 'Espaço Gourmet', 'title': 'Quartier Brooklin'}
# 2018-10-30 00:38:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/oportunidade-de-verdade!-apartamento-2-dormitorios-2938973994.html> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/oportunidade-de-verdade!-apartamento-2-dormitorios-2938973994.html>
# {'Condominio': '460',
#  'IPTU': '175',
#  'Venda': '240000',
#  'area_util': '60',
#  'banheiro': '1',
#  'city': 'Campinas',
#  'neigghborhood': 'Jardim García',
#  'privateareas': 'Churrasqueira',
#  'quarto': '2',
#  'saletype': 'Apartamento',
#  'street': 'Rua Castelnuovo 135',
#  'title': 'Oportunidade De Verdade! Apartamento 2 Dormitórios, Jardim García, '
#           'Campinas - Ap0356.',
#  'vaga': '1'}
# 2018-10-30 00:38:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/edificio-next-home-2939114189.html#map> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:38:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/edificio-next-home-2939114189.html>
# {'Condominio': '470',
#  'IPTU': '1200',
#  'Venda': '359909',
#  'age_imovel': '3',
#  'area_total': '63',
#  'area_util': '87',
#  'banheiro': '2',
#  'city': 'Curitiba',
#  'commonareas': 'Espaço Gourmet',
#  'diverseareas': 'Aceita FGTS',
#  'neigghborhood': 'Portão',
#  'privateareas': 'Cozinha Gourmet',
#  'quarto': '2',
#  'saletype': 'Apartamento',
#  'street': 'Avenida República Argentina',
#  'suite': '1',
#  'title': 'Edifício Next Home',
#  'vaga': '2'}
# 2018-10-30 00:39:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/propriedades/apartamento-a-venda-com-138-m-sup2--brooklin-sao-2939508198.html> (referer: https://www.imovelweb.com.br/imoveis.html)
# 2018-10-30 00:39:00 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imovelweb.com.br/propriedades/apartamento-a-venda-com-138-m-sup2--brooklin-sao-2939508198.html>
# {'Condominio': '1440',
#  'IPTU': '500',
#  'Venda': '1829000',
#  'area_util': '138',
#  'city': 'São Paulo',
#  'commonareas': 'Espaço Gourmet',
#  'neigghborhood': 'Brooklin',
#  'privateareas': 'Suítes',
#  'quarto': '3',
#  'saletype': 'Apartamento',
#  'street': 'AV Portugal 1048',
#  'suite': '3',
#  'title': 'Apartamento à Venda Com 138 m&sup2; - Brooklin, São Paulo.',
#  'vaga': '2'}
# 2018-10-30 00:39:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:39:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:39:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:39:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:39:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:39:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:39:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imovelweb.com.br/imoveis.html> (referer: None)
# 2018-10-30 00:39:02 [scrapy.core.engine] INFO: Closing spider (finished)
# 2018-10-30 00:39:02 [scrapy.extensions.feedexport] INFO: Stored csv feed (51 items) in: imovelwebcrawl.csv
# 2018-10-30 00:39:02 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 54742,
#  'downloader/request_count': 108,
#  'downloader/request_method_count/GET': 108,
#  'downloader/response_bytes': 3679250,
#  'downloader/response_count': 108,
#  'downloader/response_status_count/200': 77,
#  'downloader/response_status_count/301': 31,
#  'dupefilter/filtered': 924,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2018, 10, 30, 3, 39, 2, 997172),
#  'item_scraped_count': 51,
#  'log_count/DEBUG': 161,
#  'log_count/INFO': 8,
#  'request_depth_max': 1,
#  'response_received_count': 77,
#  'scheduler/dequeued': 107,
#  'scheduler/dequeued/memory': 107,
#  'scheduler/enqueued': 107,
#  'scheduler/enqueued/memory': 107,
#  'start_time': datetime.datetime(2018, 10, 30, 3, 38, 22, 657652)}
# 2018-10-30 00:39:02 [scrapy.core.engine] INFO: Spider closed (finished)
# Wall time: 40.6 s

# %% [markdown]
# So, now let's take a look in the data we scraped.

# %%
dataset = pd.read_csv ('imovelwebcrawl.csv')

# %%
dataset.head()
# Out:
#    Aluguel  Condominio   IPTU      Venda        age_imovel  area_total  \
# 0      NaN         NaN    NaN        NaN               NaN         NaN
# 1      NaN         NaN  100.0   580000.0               NaN        85.0
# 2      NaN         NaN    NaN   796000.0  Breve lançamento      2041.0
# 3      NaN       668.0  650.0  5800000.0                 2      1200.0
# 4      NaN         NaN    NaN   500000.0               NaN     31000.0
#
#    area_util  banheiro           city                commonareas diverseareas  \
# 0        NaN       NaN            NaN  Fitness/Sala de Ginástica          NaN
# 1       85.0       2.0        Niterói                        NaN          NaN
# 2     2041.0       NaN    Campo Largo                        NaN          NaN
# 3      700.0       8.0        Vinhedo            Pista de cooper          NaN
# 4    31000.0       4.0  Quatro Barras                        NaN          NaN
#
#                    neigghborhood   privateareas  quarto   saletype  \
# 0                            NaN     Escritório     NaN        NaN
# 1                         Icaraí         Esgoto     2.0       Casa
# 2                Vila Ferrari II            NaN     0.0  Comercial
# 3  Condomínio Estância Marambaia     Playground     5.0       Casa
# 4                  Palmitalzinho  Churrasqueira     2.0      Rural
#
#                       street  suite  \
# 0                        NaN    NaN
# 1  Rua Presidente Backer 184    NaN
# 2      AGOSTINHO MOCELIN 700    NaN
# 3             Sob Consulta 0    5.0
# 4   Estrada Velha Graciosa 0    NaN
#
#                                                title  vaga
# 0                                   Retrato Paulista   NaN
# 1         Casa Residencial à Venda, Icaraí, Niterói.   NaN
# 2             Comercial à Venda - na Vila Ferrari II   NaN
# 3      Casa à Venda em Condomínio Estância Marambaia   4.0
# 4  Chácara Residencial à Venda, Campininha, Quatr...   7.0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 19 columns):
# Aluguel          5 non-null float64
# Condominio       26 non-null float64
# IPTU             23 non-null float64
# Venda            42 non-null float64
# age_imovel       28 non-null object
# area_total       34 non-null float64
# area_util        44 non-null float64
# banheiro         42 non-null float64
# city             41 non-null object
# commonareas      35 non-null object
# diverseareas     14 non-null object
# neigghborhood    41 non-null object
# privateareas     40 non-null object
# quarto           44 non-null float64
# saletype         45 non-null object
# street           41 non-null object
# suite            37 non-null float64
# title            51 non-null object
# vaga             41 non-null float64
# dtypes: float64(10), object(9)
# memory usage: 7.6+ KB

# %%
dataset = dataset.dropna(axis=0, subset= ['Aluguel','Venda'], how='all').reset_index(drop=True)
# Out:
#    Aluguel  Condominio    IPTU      Venda age_imovel  area_total  area_util  \
# 0   6500.0      2500.0  5000.0  2790000.0         18      2000.0      370.0
# 1   2500.0       600.0   900.0   265000.0          3        27.0       27.0
#
#    banheiro      city                commonareas diverseareas neigghborhood  \
# 0       8.0   Vinhedo           Campo de futebol          NaN        Centro
# 1       1.0  Brasília  Fitness/Sala de Ginástica      Andares     Asa Norte
#
#   privateareas  quarto     saletype           street  suite  \
# 0    Mobiliado     4.0         Casa  Sob Consulta 25    4.0
# 1       Suítes     1.0  Apartamento     SHN QUADRA 1    1.0
#
#                                                title  vaga  price_rent_total
# 0  Casa Á Venda E para Aluguel em Condomínio Mora...   6.0            9000.0
# 1      Teste Antes: Fusion E Vision 100% Mobiliados!   1.0            3100.0

# %% [markdown]
# #### Data Manipulation
#
# Since we want to evaluate the price for each item, we will create a new column for the total price.
# - for rents the total price is the rent plus the condo.
#
# In the age column, we should act on the 'Em construção' itens.

# %%
# dataset ['pricetotal'] = pd.to_numeric(dataset['price_original'].str.split(' ', 1, expand = True)[1].str.replace('.',''))+pd.to_numeric(dataset['price_extra'].str.split(' ', 3, expand=True)[2].str.replace('.','').str.replace(',','.').fillna(0))
# dataset.loc[(dataset['filter_purchase']=='Comprar'),'pricetotal'] = dataset[(dataset['filter_purchase']=='Comprar')]['price_original'].str.split(' ', 1, expand = True)[1].str.replace('.','')

dataset['price_rent_total'] = dataset['Aluguel']+dataset['Condominio']

# %%
dataset.to_csv (path_or_buf= 'imovelweb_final.csv', index= False)

# %% [markdown]
# Also, we could create categorical columns to indicate if the product is on sale or for rent.
